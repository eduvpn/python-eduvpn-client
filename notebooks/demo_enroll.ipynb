# %%
from typing import Dict, Union
import sys
import os 
from pathlib import Path
import requests
import socket
import pandas as pd
import webbrowser
from requests_oauthlib import OAuth2Session
import gi
import tempfile
try:
    gi.require_version('NM', '1.0')
    from gi.repository import GLib, NM
except ValueError:
    print("NM not available")
    NM = None
# Out:
# NM not available

# %%
sys.path.append(str(Path().absolute().parent))

# %%
from eduvpn.oauth2 import one_request, get_open_port
from eduvpn.crypto import gen_code_challenge, gen_code_verifier, common_name_from_cert

# %% [markdown]
# # Settings

# %%
# client settings
DISCO_URI = 'https://disco.eduvpn.org/v2/'
ORGANISATION_URI = DISCO_URI + "organization_list.json"
SERVER_URI = DISCO_URI + "server_list.json"
client_id = "org.eduvpn.app.linux"
scope = ["config"]
code_challenge_method = "S256"

# %%
# our configuration
organisation = 'SURFnet bv'
server = 'Demo'
institute = 'Demo'
LANGUAGE = 'nl'
COUNTRY = "nl-NL"

# %% [markdown]
# # Utils

# %%
def extract_translation(d: Union[str, Dict[str, str]]):
    if type(d) != dict:
        return d
    for m in [COUNTRY, LANGUAGE, 'en-US', 'en']:
        try:
            return d[m]
        except KeyError:
            continue
    return list(d.values())[0]  # otherwise just return first in list

# %% [markdown]
# # server list

# %%
servers_response = requests.get(SERVER_URI)
server_list = pd.DataFrame(servers_response.json()['server_list'])
server_list['display_name'] = server_list['display_name'].apply(extract_translation)
server_list
# Out:
#          server_type                                    base_url  \
# 0    secure_internet                     https://eduvpn.rash.al/
# 1    secure_internet  https://gdpt-eduvpndev1.tnd.aarnet.edu.au/
# 2    secure_internet                     https://eduvpn.deic.dk/
# 3    secure_internet                    https://eduvpn.eenet.ee/
# 4    secure_internet                   https://eduvpn1.funet.fi/
# ..               ...                                         ...
# 60  institute_access             https://eduvpn.univ-rennes1.fr/
# 61  institute_access                      https://hku.eduvpn.nl/
# 62  institute_access                     https://eduvpn.vamk.fi/
# 63  institute_access                       https://vu.eduvpn.nl/
# 64  institute_access                     https://hiof.eduvpn.no/
#
#                                   public_key_list country_code  \
# 0   [Xv3l24gbMX8NtTnFQbWO2fGKPwKuc6EbjQDv8qw2GVk]           AL
# 1   [HpY5RKF0OzYcYUcogKzgt1MvC6CxBmDJoUBsyiKjioA]           AU
# 2   [bRTz33KIuYo_w_-AbzNtdmLDqIm11_eGiHXQniojxY4]           DK
# 3   [jGpivOdwCRoLlexYKQjulZPPP4s3d9SVBFslI6RroAo]           EE
# 4   [H4NTnM18BJgU_B3r8OBDVblBSfozB2Zu97I_ag2whmM]           FI
# ..                                            ...          ...
# 60                                            NaN          NaN
# 61                                            NaN          NaN
# 62                                            NaN          NaN
# 63                                            NaN          NaN
# 64                                            NaN          NaN
#
#                                     support_contact  \
# 0                         [mailto:helpdesk@rash.al]
# 1                                               NaN
# 2                           [mailto:eduvpn@deic.dk]
# 3                          [mailto:eduvpn@eenet.ee]
# 4                            [mailto:eduvpn@csc.fi]
# ..                                              ...
# 60            [https://assistance.univ-rennes1.fr/]
# 61                                              NaN
# 62                        [mailto:helpdesk@vamk.fi]
# 63  [mailto:servicedesk.it@vu.nl, tel:+31205980000]
# 64                      [mailto:kontakt@uninett.no]
#
#                           authentication_url_template  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   https://eduvpn1.funet.fi/Shibboleth.sso/Login?...
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#                              display_name keyword_list
# 0                                     NaN          NaN
# 1                                     NaN          NaN
# 2                                     NaN          NaN
# 3                                     NaN          NaN
# 4                                     NaN          NaN
# ..                                    ...          ...
# 60                 Université de Rennes 1          NaN
# 61     Hogeschool voor de Kunsten Utrecht          hku
# 62  VAMK - University of Applied Sciences          NaN
# 63                     Vrije Universiteit          NaN
# 64             Østfold University College          NaN
#
# [65 rows x 8 columns]

# %% [markdown]
# # institute list

# %%
institute_list = server_list[server_list['server_type'] == 'institute_access'].drop(['server_type'], axis=1)
institute_list
# Out:
#                                     base_url public_key_list country_code  \
# 15                  https://avans.eduvpn.nl/             NaN          NaN
# 16                 https://sunset.nuonet.fr/             NaN          NaN
# 17              https://eduvpn-csc.funet.fi/             NaN          NaN
# 18                   https://demo.eduvpn.nl/             NaN          NaN
# 19                   https://access.diak.fi/             NaN          NaN
# 20                    https://egi.eduvpn.nl/             NaN          NaN
# 21                  https://eduvpn.ensma.fr/             NaN          NaN
# 22                    https://eur.eduvpn.nl/             NaN          NaN
# 23                 https://fontys.eduvpn.nl/             NaN          NaN
# 24           https://eduvpn.frederick.ac.cy/             NaN          NaN
# 25           https://leduvpn.kyabirwasc.org/             NaN          NaN
# 26          https://prod-eduvpn01.geant.org/             NaN          NaN
# 27                 https://eduvpn.heanet.ie/             NaN          NaN
# 28          https://eduvpn.hs-osnabrueck.de/             NaN          NaN
# 29                 https://saxion.eduvpn.nl/             NaN          NaN
# 30                    https://hva.eduvpn.nl/             NaN          NaN
# 31                 https://vpn.ibgc.cnrs.fr/             NaN          NaN
# 32                 https://eduvpn.idi.co.ug/             NaN          NaN
# 33                    https://eduvpn.ipb.pt/             NaN          NaN
# 34                  https://vpn.jcrc.org.ug/             NaN          NaN
# 35                https://eduvpn.karelia.fi/             NaN          NaN
# 36            https://controller.eduroam.ke/             NaN          NaN
# 37         https://esciencecenter.eduvpn.nl/             NaN          NaN
# 38                 https://nikhef.eduvpn.nl/             NaN          NaN
# 39                https://eduvpn.hec.gov.pk/             NaN          NaN
# 40  https://eduvpn.perdanauniversity.edu.my/             NaN          NaN
# 41            https://eduvpn.pionier.net.pl/             NaN          NaN
# 42                  https://eduvpn.polsl.pl/             NaN          NaN
# 43                     https://ru.eduvpn.nl/             NaN          NaN
# 44               https://leduvpn.renu.ac.ug/             NaN          NaN
# 45                    https://stc.eduvpn.nl/             NaN          NaN
# 46                https://surfnet.eduvpn.nl/             NaN          NaN
# 47                   https://eduvpn.tuni.fi/             NaN          NaN
# 48                https://tudelft.eduvpn.nl/             NaN          NaN
# 49       https://eduvpn.hochschule-trier.de/             NaN          NaN
# 50                https://trimbos.eduvpn.nl/             NaN          NaN
# 51               https://eduvpn.turkuamk.fi/             NaN          NaN
# 52                https://uninett.eduvpn.no/             NaN          NaN
# 53                   https://eduvpn.unit.no/             NaN          NaN
# 54                 https://eduvpn.uii.ac.id/             NaN          NaN
# 55                    https://uva.eduvpn.nl/             NaN          NaN
# 56                 https://eduvpn.uminho.pt/             NaN          NaN
# 57                 https://eduvpn.unimes.fr/             NaN          NaN
# 58         https://eduvpn.uni-osnabrueck.de/             NaN          NaN
# 59                     https://ut.eduvpn.nl/             NaN          NaN
# 60           https://eduvpn.univ-rennes1.fr/             NaN          NaN
# 61                    https://hku.eduvpn.nl/             NaN          NaN
# 62                   https://eduvpn.vamk.fi/             NaN          NaN
# 63                     https://vu.eduvpn.nl/             NaN          NaN
# 64                   https://hiof.eduvpn.no/             NaN          NaN
#
#                                       support_contact  \
# 15  [mailto:servicepunt@avans.nl, https://servicep...
# 16    [mailto:support-technique-nuo@listes.nuonet.fr]
# 17                             [mailto:eduvpn@csc.fi]
# 18                         [mailto:eduvpn@surfnet.nl]
# 19           [mailto:tuki@diak.fi, tel:+358294696070]
# 20                                                NaN
# 21                              [mailto:dsi@ensma.fr]
# 22                                                NaN
# 23  [https://fontys.nl/fontyshelpt/IT-ondersteunin...
# 24  [mailto:support@frederick.ac.cy, tel:+35722394...
# 25  [mailto:ivan.aine@kyabirwasc.org, tel:+2567796...
# 26                              [mailto:it@geant.org]
# 27                                                NaN
# 28  [https://www.hs-osnabrueck.de/servicedesk/, te...
# 29  [tel:+31880193600, https://servicedesk.saxion....
# 30  [mailto:servicedesk-icts@hva.nl, tel:+31205951...
# 31  [https://www.ibgc.cnrs.fr/glpi/, mailto:inform...
# 32  [mailto:eduvpnsupport@idi.co.ug, tel:+25678367...
# 33  [mailto:ccom@ipb.pt, http://www.ipb.pt/si, tel...
# 34  [mailto:aatukunda@jcrc.org.ug, tel:+256789711148]
# 35                      [mailto: helpdesk@karelia.fi]
# 36     [mailto:eduvpn@kenet.or.ke, tel:+254732150500]
# 37                                                NaN
# 38                                                NaN
# 39                        [mailto:eduvpn@pern.edu.pk]
# 40      [mailto:it-helpdesk@perdanauniversity.edu.my]
# 41             [mailto:contact@eduvpn.pionier.net.pl]
# 42                                                NaN
# 43                                                NaN
# 44   [tel:+256783979515, mailto:technical@renu.ac.ug]
# 45                                                NaN
# 46                                                NaN
# 47  [mailto:it-helpdesk@tuni.fi, https://www.tuni....
# 48  [mailto:eduvpn@surfnet.nl, https://www.tudelft...
# 49  [https://www.hochschule-trier.de/rzht/it-suppo...
# 50                                                NaN
# 51                  [mailto: servicedesk@turkuamk.fi]
# 52                        [mailto:kontakt@uninett.no]
# 53                        [mailto:kontakt@uninett.no]
# 54  [mailto:itsupport@uii.ac.id, https://bsi.uii.a...
# 55  [mailto:servicedesk-icts@uva.nl, https://extra...
# 56  [mailto:servicedesk@scom.uminho.pt, tel:+35125...
# 57                          [mailto:eduvpn@unimes.fr]
# 58  [https://www.rz.uni-osnabrueck.de/dienste/bera...
# 59                                                NaN
# 60              [https://assistance.univ-rennes1.fr/]
# 61                                                NaN
# 62                          [mailto:helpdesk@vamk.fi]
# 63    [mailto:servicedesk.it@vu.nl, tel:+31205980000]
# 64                        [mailto:kontakt@uninett.no]
#
#    authentication_url_template                           display_name  \
# 15                         NaN                       Avans Hogeschool
# 16                         NaN                                  CNOUS
# 17                         NaN       CSC - IT Center for Science Ltd.
# 18                         NaN                                   Demo
# 19                         NaN                                   DIAK
# 20                         NaN                         EGI Foundation
# 21                         NaN                                  Ensma
# 22                         NaN           Erasmus University Rotterdam
# 23                         NaN                                 Fontys
# 24                         NaN                   Frederick University
# 25                         NaN     Global Surgical Initiatives, Jinja
# 26                         NaN                                  GÉANT
# 27                         NaN                                 HEAnet
# 28                         NaN                   Hochschule Osnabrück
# 29                         NaN                      Hogeschool Saxion
# 30                         NaN               Hogeschool van Amsterdam
# 31                         NaN                                   IBGC
# 32                         NaN                             IDI-Uganda
# 33                         NaN      Instituto Politécnico de Bragança
# 34                         NaN                          JCRC - Uganda
# 35                         NaN             Karelia-ammattikorkeakoulu
# 36                         NaN                                  KENET
# 37                         NaN             Netherlands eScienceCenter
# 38                         NaN                                 Nikhef
# 39                         NaN  Pakistan Education & Research Network
# 40                         NaN                     Perdana University
# 41                         NaN                                PIONIER
# 42                         NaN                    Politechnika Śląska
# 43                         NaN                   Radboud Universiteit
# 44                         NaN                                   RENU
# 45                         NaN                              STC Group
# 46                         NaN                                SURFnet
# 47                         NaN                   Tampere Universities
# 48                         NaN          Technische Universiteit Delft
# 49                         NaN   Trier University of Applied Sciences
# 50                         NaN                      Trimbos-instituut
# 51                         NaN   Turku University of Applied Sciences
# 52                         NaN                                Uninett
# 53                         NaN                                   Unit
# 54                         NaN            Universitas Islam Indonesia
# 55                         NaN             Universiteit van Amsterdam
# 56                         NaN                    University of Minho
# 57                         NaN                    University of Nimes
# 58                         NaN                University of Osnabrück
# 59                         NaN                    Universiteit Twente
# 60                         NaN                 Université de Rennes 1
# 61                         NaN     Hogeschool voor de Kunsten Utrecht
# 62                         NaN  VAMK - University of Applied Sciences
# 63                         NaN                     Vrije Universiteit
# 64                         NaN             Østfold University College
#
#    keyword_list
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# 54          NaN
# 55          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 59          NaN
# 60          NaN
# 61          hku
# 62          NaN
# 63          NaN
# 64          NaN

# %% [markdown]
# # organisation list

# %%
organisation_response = requests.get(ORGANISATION_URI)
organization_list = pd.DataFrame(organisation_response.json()['organization_list'])
organization_list['display_name'] = organization_list['display_name'].apply(extract_translation)
organization_list['keyword_list'] = organization_list['keyword_list'].apply(extract_translation)
organization_list
# Out:
#                                           display_name  \
# 0                              Danish Language Council
# 1                              Business Academy Aarhus
# 2                                          KMD DSPARE3
# 3                                      KMD DSUP_PATCH1
# 4                                         KMD DANSWRC2
# ..                                                 ...
# 732             Uganda Virus Research Institute (UVRI)
# 733                     Uganda Martyrs Hospital Lubaga
# 734  African Center of Excellence in Bioinformatics...
# 735                           Bishop Stuart University
# 736                                     Mengo Hospital
#
#                                                 org_id  \
# 0                http://idp.dsn.dk/adfs/services/trust
# 1              http://adfs.eaaa.dk/adfs/services/trust
# 2    http://dans-support-04.dans-idp-dev01.northeur...
# 3                         https://dans-idp.kmd.dk:7080
# 4    http://dans-support-02.dans-dp-dev01.northeuro...
# ..                                                 ...
# 732                  https://idp.uvri.go.ug/shibboleth
# 733      https://idp.lubagahospital.org/idp/shibboleth
# 734             https://login.ace.ac.ug/idp/shibboleth
# 735               https://idp.bsu.ac.ug/idp/shibboleth
# 736       https://idp.mengohospital.org/idp/shibboleth
#
#            secure_internet_home keyword_list
# 0       https://eduvpn.deic.dk/          NaN
# 1       https://eduvpn.deic.dk/          NaN
# 2       https://eduvpn.deic.dk/          NaN
# 3       https://eduvpn.deic.dk/          NaN
# 4       https://eduvpn.deic.dk/          NaN
# ..                          ...          ...
# 732  https://eduvpn.renu.ac.ug/          NaN
# 733  https://eduvpn.renu.ac.ug/          NaN
# 734  https://eduvpn.renu.ac.ug/          NaN
# 735  https://eduvpn.renu.ac.ug/          NaN
# 736  https://eduvpn.renu.ac.ug/          NaN
#
# [737 rows x 4 columns]

# %% [markdown]
# # Secure internet

# %%
secure_internet_list = server_list[server_list['server_type'] == 'secure_internet'].drop(['server_type'], axis=1)
secure_internet_list
# Out:
#                                       base_url  \
# 0                      https://eduvpn.rash.al/
# 1   https://gdpt-eduvpndev1.tnd.aarnet.edu.au/
# 2                      https://eduvpn.deic.dk/
# 3                     https://eduvpn.eenet.ee/
# 4                    https://eduvpn1.funet.fi/
# 5               https://eduvpn-poc.renater.fr/
# 6                   https://eduvpn1.eduvpn.de/
# 7                 https://eduvpn.myren.net.my/
# 8                    https://eduvpn.marwan.ma/
# 9                     https://guest.eduvpn.no/
# 10                    https://vpn.pern.edu.pk/
# 11                       https://eduvpn.ac.lk/
# 12                      https://nl.eduvpn.org/
# 13                  https://eduvpn.renu.ac.ug/
# 14                     https://eduvpn.uran.ua/
#
#                                   public_key_list country_code  \
# 0   [Xv3l24gbMX8NtTnFQbWO2fGKPwKuc6EbjQDv8qw2GVk]           AL
# 1   [HpY5RKF0OzYcYUcogKzgt1MvC6CxBmDJoUBsyiKjioA]           AU
# 2   [bRTz33KIuYo_w_-AbzNtdmLDqIm11_eGiHXQniojxY4]           DK
# 3   [jGpivOdwCRoLlexYKQjulZPPP4s3d9SVBFslI6RroAo]           EE
# 4   [H4NTnM18BJgU_B3r8OBDVblBSfozB2Zu97I_ag2whmM]           FI
# 5   [ePVNzE15h0yS6Xf3s8nJWmc8V6FeFziA3TZr0uOacFg]           FR
# 6   [QjJHMit3vhHwLKi-fu2dXXSxMxnkskFVS3hMwyCnWQs]           DE
# 7   [2WsUQpiUofRZ9IWZ8qQaOeQG4-RMy981QguOEMg4-e4]           MY
# 8   [aX-El_yRPdcUDF5S2smQ-9U7BzB35_1RtFYSjbHfEz8]           MA
# 9   [qOLCcqXWZm9nmjsrwiJQxxWD606vDEJ2MIcc85oJmnE]           NO
# 10  [LKWFZblpTFvFDY4E_0tnD8yHpK-iOSrJop_1x-A4cQ8]           PK
# 11  [drq4-3Sg35UJHxVfx-ssR3onjHihCVH-zjXYPnEfudI]           LK
# 12  [O53DTgB956magGaWpVCKtdKIMYqywS3FMAC5fHXdFNg]           NL
# 13  [4plEYRW26amB1-PcRRxWcKlEcDXsUO4yNHnf0VA2MPE]           UG
# 14  [gCUDsmSIn0pVPc4C-QNLsBil6WxkwDDwxfvTC262p9U]           UA
#
#                                       support_contact  \
# 0                           [mailto:helpdesk@rash.al]
# 1                                                 NaN
# 2                             [mailto:eduvpn@deic.dk]
# 3                            [mailto:eduvpn@eenet.ee]
# 4                              [mailto:eduvpn@csc.fi]
# 5                    [https://assistance.renater.fr/]
# 6         [mailto:eduvpn@dfn.de, tel:+49308842999120]
# 7                      [mailto:helpdesk@myren.net.my]
# 8   [mailto:eduvpn-support@marwan.ma, tel:+2127000...
# 9                         [mailto:kontakt@uninett.no]
# 10                        [mailto:eduvpn@pern.edu.pk]
# 11                        [mailto:eduvpn@learn.ac.lk]
# 12                         [mailto:eduvpn@surfnet.nl]
# 13   [mailto:technical@renu.ac.ug, tel:+256783979515]
# 14       [mailto:dopomoga@uran.ua, tel:+380442049816]
#
#                           authentication_url_template display_name  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4   https://eduvpn1.funet.fi/Shibboleth.sso/Login?...          NaN
# 5   https://eduvpn-poc.renater.fr/Shibboleth.sso/L...          NaN
# 6   https://eduvpn1.eduvpn.de/saml/login?ReturnTo=...          NaN
# 7   https://eduvpn.myren.net.my/Shibboleth.sso/Log...          NaN
# 8   https://eduvpn.marwan.ma/saml/login?ReturnTo=@...          NaN
# 9                                                 NaN          NaN
# 10  https://vpn.pern.edu.pk/Shibboleth.sso/Login?e...          NaN
# 11  https://eduvpn.ac.lk/Shibboleth.sso/Login?enti...          NaN
# 12  https://nl.eduvpn.org/php-saml-sp/login?Return...          NaN
# 13  https://eduvpn.renu.ac.ug/Shibboleth.sso/Login...          NaN
# 14                                                NaN          NaN
#
#    keyword_list
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN

# %% [markdown]
# # make selection

# %%
institute_info = institute_list[institute_list['display_name'] == institute]
institute_info
# Out:
#                    base_url public_key_list country_code  \
# 18  https://demo.eduvpn.nl/             NaN          NaN
#
#                support_contact authentication_url_template display_name  \
# 18  [mailto:eduvpn@surfnet.nl]                         NaN         Demo
#
#    keyword_list
# 18          NaN

# %% [markdown]
# ## or in case you select an organisation

# %%
organisation_info = organization_list[organization_list['display_name'] == organisation]
organisation_info
# Out:
#     display_name                  org_id    secure_internet_home  \
# 711   SURFnet bv  https://idp.surfnet.nl  https://nl.eduvpn.org/
#
#                           keyword_list
# 711  SURFnet bv SURF konijn powered by

# %%
info_base_url = institute_info['base_url'].iloc[0]

# %%
info_url = info_base_url + '.well-known/vpn-user-portal'
info = requests.get(info_url).json()['api']['http://eduvpn.org/api#2']

# %%
api_base_uri = info['api_base_uri']
token_endpoint = info['token_endpoint']
authorization_endpoint = info['authorization_endpoint']

# %%
port = get_open_port()
redirect_uri = f'http://127.0.0.1:{port}/callback'

# %%
oauth = OAuth2Session(client_id, redirect_uri=redirect_uri, auto_refresh_url=token_endpoint, scope=scope)

# %%
code_verifier = gen_code_verifier()
code_challenge = gen_code_challenge(code_verifier)
authorization_url, state = oauth.authorization_url(url=authorization_endpoint,
                                                   code_challenge_method=code_challenge_method,
                                                   code_challenge=code_challenge)

# %%
webbrowser.open(authorization_url)
response = one_request(port, lets_connect=False)
# Out:
# 127.0.0.1 - - [06/Nov/2020 14:36:14] "GET /callback?code=eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCIsImtpZCI6IldMQTA5RWVfWHdoU0ZYalBOZ2ExT3lXRW40a1pUZ2xNR3ppR1RtRnM5MEEifQ.....FWoaLGh1QEneSd8uZF04XEHMsbNozBEJBNspCeFw0W9xHDLeyjp9sXC2SjaBBlSlx14GNBwXtSBDpw_4RrW4Cw&state=b73GF3UhmoWZorTgwT2O2AuzuzCHnN HTTP/1.1" 200 -

# %%
code = response['code'][0]
assert(state == response['state'][0])

# %%
token = oauth.fetch_token(token_url=token_endpoint,
                          code=code,
                          code_verifier=code_verifier,
                          client_id=oauth.client_id,
                          include_client_id=True,
                          )

# %% [markdown]
# # profile list

# %%
profile_list_response = oauth.get(api_base_uri + '/profile_list')

# %%
profile_list_response.json()['profile_list']['data']
# Out:
# [{'profile_id': 'internet',
#   'display_name': 'internet',
#   'two_factor': False,
#   'default_gateway': True},
#  {'profile_id': 'routes',
#   'display_name': 'No rfc1918 routes',
#   'two_factor': False,
#   'default_gateway': False}]

# %%
response = oauth.post(api_base_uri + '/create_keypair')
keypair = response.json()['create_keypair']['data']
private_key = keypair['private_key']
certificate = keypair['certificate']
common_name = common_name_from_cert(certificate.encode('ascii'))

# %% [markdown]
# # profile config

# %%
profile_id = 'internet'
response = oauth.get(api_base_uri + f'/profile_config?profile_id={profile_id}')
config = response.text

# %% [markdown]
# # check_certificate

# %%
response = oauth.get(api_base_uri + f'/check_certificate?common_name={common_name}')
assert(response.json()['check_certificate']['data']['is_valid'])

# %% [markdown]
# # system_messages

# %%
response = oauth.get(api_base_uri + '/system_messages')

# %%
response.json()['system_messages']['data']
# Out:
# [{'type': 'notification',
#   'date_time': '2019-05-16T07:59:48Z',
#   'message': 'Welcome to the eduVPN demo server by SURFnet. If you have any questions, please let us know by mailing us on eduvpn@surfnet.nl.'}]

# %% [markdown]
# # write networkmanager config

# %%
tmp = tempfile.NamedTemporaryFile(mode='w+t')
tmp.writelines(config)
tmp.seek(0)
filename = tmp.name

# %%
connection = None
for vpn_info in NM.VpnPluginInfo.list_load():
    print("TRY:  plugin %s" % (vpn_info.get_filename()))
    try:
        vpn_plugin = vpn_info.load_editor_plugin()
    except Exception as e:
        print("SKIP: cannot load plugin: %s" % (e))
        continue
    try:
        connection = vpn_plugin.import_(filename)
    except Exception as e:
        print("SKIP: failure to import %s" % (e))
        continue
    break

if connection is None:
    print("None of the VPN plugins was able to import \"%s\"" % (filename))
    sys.exit(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-a0c86829b909> in <module>
#       1 connection = None
# ----> 2 for vpn_info in NM.VpnPluginInfo.list_load():
#       3     print("TRY:  plugin %s" % (vpn_info.get_filename()))
#       4     try:
#       5         vpn_plugin = vpn_info.load_editor_plugin()
#
# AttributeError: 'NoneType' object has no attribute 'VpnPluginInfo'

# %%
connection.normalize()

print("connection imported from \"%s\" using plugin \"%s\" (\"%s\", %s)" % (filename, vpn_info.get_filename(), connection.get_id(), connection.get_uuid()))

client = NM.Client.new(None)

main_loop = GLib.MainLoop()

def added_cb(client, result, data):
    try:
        client.add_connection_finish(result)
        print("The connection profile has been successfully added to NetworkManager.")
    except Exception as e:
        print("ERROR: failed to add connection: %s\n" % e)
    main_loop.quit()

client.add_connection_async(connection, True, None, added_cb, None)

main_loop.run()
