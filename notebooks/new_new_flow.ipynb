# %%
from typing import Dict, Union
import sys
import os 
from pathlib import Path
import requests
import socket
import pandas as pd
import webbrowser
from requests_oauthlib import OAuth2Session
import gi
import tempfile
gi.require_version('NM', '1.0')
from gi.repository import GLib, NM

# %%
sys.path.append(str(Path().absolute().parent))

# %%
from eduvpn.oauth2 import one_request, get_open_port
from eduvpn.crypto import gen_code_challenge, gen_code_verifier, common_name_from_cert

# %% [markdown]
# # Settings

# %%
# client settings
DISCO_URI = 'https://disco.eduvpn.org/'
ORGANISATION_URI = DISCO_URI + "organization_list.json"
SERVER_URI = DISCO_URI + "server_list.json"
client_id = "org.eduvpn.app.linux"
scope = ["config"]
code_challenge_method = "S256"

# %%
# our configuration
organisation = 'SURFnet bv'
server = 'Demo'
institute = 'Demo'
LANGUAGE = 'nl'
COUNTRY = "nl-NL"

# %% [markdown]
# # Utils

# %%
def extract_translation(d: Union[str, Dict[str, str]]):
    if type(d) != dict:
        return d
    for m in [COUNTRY, LANGUAGE, 'en-US', 'en']:
        try:
            return d[m]
        except KeyError:
            continue
    return list(d.values())[0]  # otherwise just return first in list

# %% [markdown]
# # server list

# %%
servers_response = requests.get(SERVER_URI)
server_list = pd.DataFrame(servers_response.json()['server_list'])
server_list['display_name'] = server_list['display_name'].apply(extract_translation)
server_list
# Out:
#          server_type                                    base_url  \
# 0    secure_internet                     https://eduvpn.rash.al/
# 1    secure_internet  https://gdpt-eduvpndev1.tnd.aarnet.edu.au/
# 2    secure_internet                     https://eduvpn.deic.dk/
# 3    secure_internet                    https://eduvpn.eenet.ee/
# 4    secure_internet                   https://eduvpn1.funet.fi/
# 5    secure_internet              https://eduvpn-poc.renater.fr/
# 6    secure_internet                  https://eduvpn1.eduvpn.de/
# 7    secure_internet                   https://eduvpn.marwan.ma/
# 8    secure_internet                    https://guest.eduvpn.no/
# 9    secure_internet                    https://vpn.pern.edu.pk/
# 10   secure_internet                       https://eduvpn.ac.lk/
# 11   secure_internet                      https://nl.eduvpn.org/
# 12   secure_internet                  https://eduvpn.renu.ac.ug/
# 13   secure_internet                     https://eduvpn.uran.ua/
# 14  institute_access                   https://sunset.nuonet.fr/
# 15  institute_access                https://eduvpn-csc.funet.fi/
# 16  institute_access                     https://demo.eduvpn.nl/
# 17  institute_access                     https://access.diak.fi/
# 18  institute_access                   https://differ.eduvpn.nl/
# 19  institute_access                      https://egi.eduvpn.nl/
# 20  institute_access                    https://eduvpn.ensma.fr/
# 21  institute_access                      https://eur.eduvpn.nl/
# 22  institute_access            https://prod-eduvpn01.geant.org/
# 23  institute_access                   https://eduvpn.heanet.ie/
# 24  institute_access            https://eduvpn.hs-osnabrueck.de/
# 25  institute_access                      https://eduvpn.ipb.pt/
# 26  institute_access           https://esciencecenter.eduvpn.nl/
# 27  institute_access                   https://nikhef.eduvpn.nl/
# 28  institute_access                  https://eduvpn.hec.gov.pk/
# 29  institute_access    https://eduvpn.perdanauniversity.edu.my/
# 30  institute_access              https://eduvpn.pionier.net.pl/
# 31  institute_access                    https://eduvpn.polsl.pl/
# 32  institute_access                       https://ru.eduvpn.nl/
# 33  institute_access                 https://leduvpn.renu.ac.ug/
# 34  institute_access                      https://stc.eduvpn.nl/
# 35  institute_access                  https://surfnet.eduvpn.nl/
# 36  institute_access                     https://eduvpn.tuni.fi/
# 37  institute_access         https://eduvpn.hochschule-trier.de/
# 38  institute_access                  https://trimbos.eduvpn.nl/
# 39  institute_access                  https://uninett.eduvpn.no/
# 40  institute_access                     https://eduvpn.unit.no/
# 41  institute_access                   https://eduvpn.uminho.pt/
# 42  institute_access                   https://eduvpn.unimes.fr/
# 43  institute_access           https://eduvpn.uni-osnabrueck.de/
# 44  institute_access                       https://ut.eduvpn.nl/
# 45  institute_access                      https://hku.eduvpn.nl/
# 46  institute_access                     https://eduvpn.vamk.fi/
# 47  institute_access                       https://vu.eduvpn.nl/
# 48  institute_access                     https://hiof.eduvpn.no/
#
#                              display_name  \
# 0                                 Albania
# 1                               Australië
# 2                              Denemarken
# 3                                 Estonia
# 4                                 Finland
# 5                               Frankrijk
# 6                               Duitsland
# 7                                 Marokko
# 8                               Noorwegen
# 9                                Pakistan
# 10                              Sri Lanka
# 11                              Nederland
# 12                                Oeganda
# 13                               Oekraïne
# 14                                  CNOUS
# 15       CSC - IT Center for Science Ltd.
# 16                                   Demo
# 17                                   DIAK
# 18                                 DIFFER
# 19                         EGI Foundation
# 20                                  Ensma
# 21           Erasmus University Rotterdam
# 22                                  GÉANT
# 23                                 HEAnet
# 24                   Hochschule Osnabrück
# 25      Instituto Politécnico de Bragança
# 26             Netherlands eScienceCenter
# 27                                 Nikhef
# 28  Pakistan Education & Research Network
# 29                     Perdana University
# 30                                PIONIER
# 31                    Politechnika Śląska
# 32                   Radboud Universiteit
# 33                                   RENU
# 34                              STC Group
# 35                                SURFnet
# 36                   Tampere Universities
# 37   Trier University of Applied Sciences
# 38                      Trimbos-instituut
# 39                                Uninett
# 40                                   Unit
# 41                    University of Minho
# 42                    University of Nimes
# 43                University of Osnabrück
# 44                    Universiteit Twente
# 45     Hogeschool voor de Kunsten Utrecht
# 46  VAMK - University of Applied Sciences
# 47                     Vrije Universiteit
# 48             Østfold University College
#
#                                   public_key_list  \
# 0   [Xv3l24gbMX8NtTnFQbWO2fGKPwKuc6EbjQDv8qw2GVk]
# 1   [HpY5RKF0OzYcYUcogKzgt1MvC6CxBmDJoUBsyiKjioA]
# 2   [bRTz33KIuYo_w_-AbzNtdmLDqIm11_eGiHXQniojxY4]
# 3   [jGpivOdwCRoLlexYKQjulZPPP4s3d9SVBFslI6RroAo]
# 4   [H4NTnM18BJgU_B3r8OBDVblBSfozB2Zu97I_ag2whmM]
# 5   [ePVNzE15h0yS6Xf3s8nJWmc8V6FeFziA3TZr0uOacFg]
# 6   [QjJHMit3vhHwLKi-fu2dXXSxMxnkskFVS3hMwyCnWQs]
# 7   [aX-El_yRPdcUDF5S2smQ-9U7BzB35_1RtFYSjbHfEz8]
# 8   [qOLCcqXWZm9nmjsrwiJQxxWD606vDEJ2MIcc85oJmnE]
# 9   [LKWFZblpTFvFDY4E_0tnD8yHpK-iOSrJop_1x-A4cQ8]
# 10  [drq4-3Sg35UJHxVfx-ssR3onjHihCVH-zjXYPnEfudI]
# 11  [O53DTgB956magGaWpVCKtdKIMYqywS3FMAC5fHXdFNg]
# 12  [4plEYRW26amB1-PcRRxWcKlEcDXsUO4yNHnf0VA2MPE]
# 13  [gCUDsmSIn0pVPc4C-QNLsBil6WxkwDDwxfvTC262p9U]
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
# 32                                            NaN
# 33                                            NaN
# 34                                            NaN
# 35                                            NaN
# 36                                            NaN
# 37                                            NaN
# 38                                            NaN
# 39                                            NaN
# 40                                            NaN
# 41                                            NaN
# 42                                            NaN
# 43                                            NaN
# 44                                            NaN
# 45                                            NaN
# 46                                            NaN
# 47                                            NaN
# 48                                            NaN
#
#                                       support_contact
# 0                           [mailto:helpdesk@rash.al]
# 1                                                 NaN
# 2                             [mailto:eduvpn@deic.dk]
# 3                            [mailto:eduvpn@eenet.ee]
# 4                              [mailto:eduvpn@csc.fi]
# 5                    [https://assistance.renater.fr/]
# 6         [mailto:eduvpn@dfn.de, tel:+49308842999120]
# 7   [mailto:eduvpn-support@marwan.ma, tel:+2127000...
# 8                         [mailto:kontakt@uninett.no]
# 9                         [mailto:eduvpn@pern.edu.pk]
# 10                        [mailto:eduvpn@learn.ac.lk]
# 11                         [mailto:eduvpn@surfnet.nl]
# 12   [mailto:technical@renu.ac.ug, tel:+256783979515]
# 13       [mailto:dopomoga@uran.ua, tel:+380442049816]
# 14    [mailto:support-technique-nuo@listes.nuonet.fr]
# 15                             [mailto:eduvpn@csc.fi]
# 16                         [mailto:eduvpn@surfnet.nl]
# 17           [mailto:tuki@diak.fi, tel:+358294696070]
# 18                                                NaN
# 19                                                NaN
# 20                              [mailto:dsi@ensma.fr]
# 21                                                NaN
# 22                              [mailto:it@geant.org]
# 23                                                NaN
# 24  [https://www.hs-osnabrueck.de/servicedesk/, te...
# 25  [mailto:ccom@ipb.pt, http://www.ipb.pt/si, tel...
# 26                                                NaN
# 27                                                NaN
# 28                        [mailto:eduvpn@pern.edu.pk]
# 29      [mailto:it-helpdesk@perdanauniversity.edu.my]
# 30             [mailto:contact@eduvpn.pionier.net.pl]
# 31                                                NaN
# 32                                                NaN
# 33   [tel:+256783979515, mailto:technical@renu.ac.ug]
# 34                                                NaN
# 35                                                NaN
# 36  [mailto:it-helpdesk@tuni.fi, https://www.tuni....
# 37  [https://www.hochschule-trier.de/rzht/it-suppo...
# 38                                                NaN
# 39                        [mailto:kontakt@uninett.no]
# 40                        [mailto:kontakt@uninett.no]
# 41  [mailto:servicedesk@scom.uminho.pt, tel:+35125...
# 42                          [mailto:eduvpn@unimes.fr]
# 43  [https://www.rz.uni-osnabrueck.de/dienste/bera...
# 44                                                NaN
# 45                                                NaN
# 46                          [mailto:helpdesk@vamk.fi]
# 47    [mailto:servicedesk.it@vu.nl, tel:+31205980000]
# 48                        [mailto:kontakt@uninett.no]

# %% [markdown]
# # institute list

# %%
institute_list = server_list[server_list['server_type'] == 'institute_access'].drop(['server_type'], axis=1)
institute_list
# Out:
#                                     base_url  \
# 14                 https://sunset.nuonet.fr/
# 15              https://eduvpn-csc.funet.fi/
# 16                   https://demo.eduvpn.nl/
# 17                   https://access.diak.fi/
# 18                 https://differ.eduvpn.nl/
# 19                    https://egi.eduvpn.nl/
# 20                  https://eduvpn.ensma.fr/
# 21                    https://eur.eduvpn.nl/
# 22          https://prod-eduvpn01.geant.org/
# 23                 https://eduvpn.heanet.ie/
# 24          https://eduvpn.hs-osnabrueck.de/
# 25                    https://eduvpn.ipb.pt/
# 26         https://esciencecenter.eduvpn.nl/
# 27                 https://nikhef.eduvpn.nl/
# 28                https://eduvpn.hec.gov.pk/
# 29  https://eduvpn.perdanauniversity.edu.my/
# 30            https://eduvpn.pionier.net.pl/
# 31                  https://eduvpn.polsl.pl/
# 32                     https://ru.eduvpn.nl/
# 33               https://leduvpn.renu.ac.ug/
# 34                    https://stc.eduvpn.nl/
# 35                https://surfnet.eduvpn.nl/
# 36                   https://eduvpn.tuni.fi/
# 37       https://eduvpn.hochschule-trier.de/
# 38                https://trimbos.eduvpn.nl/
# 39                https://uninett.eduvpn.no/
# 40                   https://eduvpn.unit.no/
# 41                 https://eduvpn.uminho.pt/
# 42                 https://eduvpn.unimes.fr/
# 43         https://eduvpn.uni-osnabrueck.de/
# 44                     https://ut.eduvpn.nl/
# 45                    https://hku.eduvpn.nl/
# 46                   https://eduvpn.vamk.fi/
# 47                     https://vu.eduvpn.nl/
# 48                   https://hiof.eduvpn.no/
#
#                              display_name public_key_list  \
# 14                                  CNOUS             NaN
# 15       CSC - IT Center for Science Ltd.             NaN
# 16                                   Demo             NaN
# 17                                   DIAK             NaN
# 18                                 DIFFER             NaN
# 19                         EGI Foundation             NaN
# 20                                  Ensma             NaN
# 21           Erasmus University Rotterdam             NaN
# 22                                  GÉANT             NaN
# 23                                 HEAnet             NaN
# 24                   Hochschule Osnabrück             NaN
# 25      Instituto Politécnico de Bragança             NaN
# 26             Netherlands eScienceCenter             NaN
# 27                                 Nikhef             NaN
# 28  Pakistan Education & Research Network             NaN
# 29                     Perdana University             NaN
# 30                                PIONIER             NaN
# 31                    Politechnika Śląska             NaN
# 32                   Radboud Universiteit             NaN
# 33                                   RENU             NaN
# 34                              STC Group             NaN
# 35                                SURFnet             NaN
# 36                   Tampere Universities             NaN
# 37   Trier University of Applied Sciences             NaN
# 38                      Trimbos-instituut             NaN
# 39                                Uninett             NaN
# 40                                   Unit             NaN
# 41                    University of Minho             NaN
# 42                    University of Nimes             NaN
# 43                University of Osnabrück             NaN
# 44                    Universiteit Twente             NaN
# 45     Hogeschool voor de Kunsten Utrecht             NaN
# 46  VAMK - University of Applied Sciences             NaN
# 47                     Vrije Universiteit             NaN
# 48             Østfold University College             NaN
#
#                                       support_contact
# 14    [mailto:support-technique-nuo@listes.nuonet.fr]
# 15                             [mailto:eduvpn@csc.fi]
# 16                         [mailto:eduvpn@surfnet.nl]
# 17           [mailto:tuki@diak.fi, tel:+358294696070]
# 18                                                NaN
# 19                                                NaN
# 20                              [mailto:dsi@ensma.fr]
# 21                                                NaN
# 22                              [mailto:it@geant.org]
# 23                                                NaN
# 24  [https://www.hs-osnabrueck.de/servicedesk/, te...
# 25  [mailto:ccom@ipb.pt, http://www.ipb.pt/si, tel...
# 26                                                NaN
# 27                                                NaN
# 28                        [mailto:eduvpn@pern.edu.pk]
# 29      [mailto:it-helpdesk@perdanauniversity.edu.my]
# 30             [mailto:contact@eduvpn.pionier.net.pl]
# 31                                                NaN
# 32                                                NaN
# 33   [tel:+256783979515, mailto:technical@renu.ac.ug]
# 34                                                NaN
# 35                                                NaN
# 36  [mailto:it-helpdesk@tuni.fi, https://www.tuni....
# 37  [https://www.hochschule-trier.de/rzht/it-suppo...
# 38                                                NaN
# 39                        [mailto:kontakt@uninett.no]
# 40                        [mailto:kontakt@uninett.no]
# 41  [mailto:servicedesk@scom.uminho.pt, tel:+35125...
# 42                          [mailto:eduvpn@unimes.fr]
# 43  [https://www.rz.uni-osnabrueck.de/dienste/bera...
# 44                                                NaN
# 45                                                NaN
# 46                          [mailto:helpdesk@vamk.fi]
# 47    [mailto:servicedesk.it@vu.nl, tel:+31205980000]
# 48                        [mailto:kontakt@uninett.no]

# %% [markdown]
# # organisation list

# %%
organisation_response = requests.get(ORGANISATION_URI)
organization_list = pd.DataFrame(organisation_response.json()['organization_list'])
organization_list['display_name'] = organization_list['display_name'].apply(extract_translation)
organization_list['keyword_list'] = organization_list['keyword_list'].apply(extract_translation)
organization_list
# Out:
#                                           display_name  \
# 0                              Business Academy Aarhus
# 1                                          KMD DSPARE3
# 2                                      KMD DSUP_PATCH1
# 3                                         KMD DANSWRC2
# 4                   IBA International Business Academy
# ..                                                 ...
# 572                              Lentiz Onderwijsgroep
# 573                                   Stichting Nuffic
# 574                                 Hogeschool Utrecht
# 575      Rijksinstituut voor Volksgezondheid en Milieu
# 576  https://eva-saml-idp.eduroam.nl/simplesamlphp/...
#
#                                                 org_id  \
# 0              http://adfs.eaaa.dk/adfs/services/trust
# 1    http://dans-support-04.dans-idp-dev01.northeur...
# 2                         https://dans-idp.kmd.dk:7080
# 3    http://dans-support-02.dans-dp-dev01.northeuro...
# 4              http://sso.basyd.dk/adfs/services/trust
# ..                                                 ...
# 572      http://adfs.mijnlentiz.nl/adfs/services/trust
# 573  https://sts.windows.net/0b883569-39c0-4403-a6a...
# 574              https://sts.hu.nl/adfs/services/trust
# 575              http://fs.rivm.nl/adfs/services/trust
# 576  https://eva-saml-idp.eduroam.nl/simplesamlphp/...
#
#         secure_internet_home  \
# 0    https://eduvpn.deic.dk/
# 1    https://eduvpn.deic.dk/
# 2    https://eduvpn.deic.dk/
# 3    https://eduvpn.deic.dk/
# 4    https://eduvpn.deic.dk/
# ..                       ...
# 572   https://nl.eduvpn.org/
# 573   https://nl.eduvpn.org/
# 574   https://nl.eduvpn.org/
# 575   https://nl.eduvpn.org/
# 576   https://nl.eduvpn.org/
#
#                                           keyword_list
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 572                              lentiz onderwijsgroep
# 573                                   nuffic ep unesco
# 574  hogeschool hu hogeschoolutrecht hu university ...
# 575                   rivm volk gezondheid milieu rijk
# 576                                                NaN
#
# [577 rows x 4 columns]

# %% [markdown]
# # Secure internet

# %%
secure_internet_list = server_list[server_list['server_type'] == 'secure_internet'].drop(['server_type'], axis=1)
secure_internet_list
# Out:
#                                       base_url display_name  \
# 0                      https://eduvpn.rash.al/      Albania
# 1   https://gdpt-eduvpndev1.tnd.aarnet.edu.au/    Australië
# 2                      https://eduvpn.deic.dk/   Denemarken
# 3                     https://eduvpn.eenet.ee/      Estonia
# 4                    https://eduvpn1.funet.fi/      Finland
# 5               https://eduvpn-poc.renater.fr/    Frankrijk
# 6                   https://eduvpn1.eduvpn.de/    Duitsland
# 7                    https://eduvpn.marwan.ma/      Marokko
# 8                     https://guest.eduvpn.no/    Noorwegen
# 9                     https://vpn.pern.edu.pk/     Pakistan
# 10                       https://eduvpn.ac.lk/    Sri Lanka
# 11                      https://nl.eduvpn.org/    Nederland
# 12                  https://eduvpn.renu.ac.ug/      Oeganda
# 13                     https://eduvpn.uran.ua/     Oekraïne
#
#                                   public_key_list  \
# 0   [Xv3l24gbMX8NtTnFQbWO2fGKPwKuc6EbjQDv8qw2GVk]
# 1   [HpY5RKF0OzYcYUcogKzgt1MvC6CxBmDJoUBsyiKjioA]
# 2   [bRTz33KIuYo_w_-AbzNtdmLDqIm11_eGiHXQniojxY4]
# 3   [jGpivOdwCRoLlexYKQjulZPPP4s3d9SVBFslI6RroAo]
# 4   [H4NTnM18BJgU_B3r8OBDVblBSfozB2Zu97I_ag2whmM]
# 5   [ePVNzE15h0yS6Xf3s8nJWmc8V6FeFziA3TZr0uOacFg]
# 6   [QjJHMit3vhHwLKi-fu2dXXSxMxnkskFVS3hMwyCnWQs]
# 7   [aX-El_yRPdcUDF5S2smQ-9U7BzB35_1RtFYSjbHfEz8]
# 8   [qOLCcqXWZm9nmjsrwiJQxxWD606vDEJ2MIcc85oJmnE]
# 9   [LKWFZblpTFvFDY4E_0tnD8yHpK-iOSrJop_1x-A4cQ8]
# 10  [drq4-3Sg35UJHxVfx-ssR3onjHihCVH-zjXYPnEfudI]
# 11  [O53DTgB956magGaWpVCKtdKIMYqywS3FMAC5fHXdFNg]
# 12  [4plEYRW26amB1-PcRRxWcKlEcDXsUO4yNHnf0VA2MPE]
# 13  [gCUDsmSIn0pVPc4C-QNLsBil6WxkwDDwxfvTC262p9U]
#
#                                       support_contact
# 0                           [mailto:helpdesk@rash.al]
# 1                                                 NaN
# 2                             [mailto:eduvpn@deic.dk]
# 3                            [mailto:eduvpn@eenet.ee]
# 4                              [mailto:eduvpn@csc.fi]
# 5                    [https://assistance.renater.fr/]
# 6         [mailto:eduvpn@dfn.de, tel:+49308842999120]
# 7   [mailto:eduvpn-support@marwan.ma, tel:+2127000...
# 8                         [mailto:kontakt@uninett.no]
# 9                         [mailto:eduvpn@pern.edu.pk]
# 10                        [mailto:eduvpn@learn.ac.lk]
# 11                         [mailto:eduvpn@surfnet.nl]
# 12   [mailto:technical@renu.ac.ug, tel:+256783979515]
# 13       [mailto:dopomoga@uran.ua, tel:+380442049816]

# %% [markdown]
# # make selection

# %%
institute_info = institute_access_list[institute_access_list['display_name'] == institute]
institute_info
# Out:
#                   base_uri display_name  \
# 2  https://demo.eduvpn.nl/         Demo
#
#                                           logo             support_contact
# 2  https://static.eduvpn.nl/disco/img/demo.png  [mailto:eduvpn@surfnet.nl]

# %% [markdown]
# ## or in case you select an organisation

# %%
organisation_info = organization_list[organization_list['display_name'] == organisation]
organisation_info
# Out:
#     display_name                  org_id    secure_internet_home  \
# 561   SURFnet bv  https://idp.surfnet.nl  https://nl.eduvpn.org/
#
#                           keyword_list
# 561  SURFnet bv SURF konijn powered by

# %%
info_base_url = institute_info['base_uri'].iloc[0]

# %%
info_url = info_base_url + 'info.json'
info = requests.get(info_url).json()['api']['http://eduvpn.org/api#2']

# %%
api_base_uri = info['api_base_uri']
token_endpoint = info['token_endpoint']
authorization_endpoint = info['authorization_endpoint']

# %%
port = get_open_port()
redirect_uri = f'http://127.0.0.1:{port}/callback'

# %%
oauth = OAuth2Session(client_id, redirect_uri=redirect_uri, auto_refresh_url=token_endpoint, scope=scope)

# %%
code_verifier = gen_code_verifier()
code_challenge = gen_code_challenge(code_verifier)
authorization_url, state = oauth.authorization_url(url=authorization_endpoint,
                                                   code_challenge_method=code_challenge_method,
                                                   code_challenge=code_challenge)

# %%
webbrowser.open(authorization_url)
# Out:
# True

# %%
response = one_request(port, lets_connect=False)
# Out:
# 127.0.0.1 - - [04/May/2020 12:07:02] "GET /callback?code=eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCIsImtpZCI6IldMQTA5RWVfWHdoU0ZYalBOZ2ExT3lXRW40a1pUZ2xNR3ppR1RtRnM5MEEifQ.....8Mm3-GXbVhkbGoHrfaI2pSN3Xaux-M-5Z3lnorxv_JOQLl-KsAApTHY7S9rkzQqjdBznyZNRQII3wSo1UmJKDQ&state=5Wd5AYqOHagqeX27IKTgMbkNRdS9Vx HTTP/1.1" 200 -

# %%
code = response['code'][0]

# %%
assert(state == response['state'][0])

# %%
token = oauth.fetch_token(token_url=token_endpoint,
                          code=code,
                          code_verifier=code_verifier,
                          client_id=oauth.client_id,
                          include_client_id=True,
                          )

# %% [markdown]
# # profile list

# %%
profile_list_response = oauth.get(api_base_uri + '/profile_list')

# %%
profile_list_response.json()['profile_list']['data']
# Out:
# [{'profile_id': 'internet', 'display_name': 'internet', 'two_factor': False},
#  {'profile_id': 'routes',
#   'display_name': 'No rfc1918 routes',
#   'two_factor': False}]

# %%
response = oauth.post(api_base_uri + '/create_keypair')
keypair = response.json()['create_keypair']['data']
private_key = keypair['private_key']
certificate = keypair['certificate']
common_name = common_name_from_cert(certificate.encode('ascii'))

# %% [markdown]
# # profile config

# %%
profile_id = 'internet'
response = oauth.get(api_base_uri + f'/profile_config?profile_id={profile_id}')
config = response.text

# %% [markdown]
# # check_certificate

# %%
response = oauth.get(api_base_uri + f'/check_certificate?common_name={common_name}')
assert(response.json()['check_certificate']['data']['is_valid'])

# %% [markdown]
# # system_messages

# %%
response = oauth.get(api_base_uri + '/system_messages')

# %%
response.json()['system_messages']['data']
# Out:
# [{'type': 'notification',
#   'date_time': '2019-05-16T07:59:48Z',
#   'message': 'Welcome to the eduVPN demo server by SURFnet. If you have any questions, please let us know by mailing us on eduvpn@surfnet.nl.'}]

# %% [markdown]
# # write networkmanager config

# %%
tmp = tempfile.NamedTemporaryFile(mode='w+t')
tmp.writelines(config)
tmp.seek(0)
filename = tmp.name

# %%
connection = None
for vpn_info in NM.VpnPluginInfo.list_load():
    print("TRY:  plugin %s" % (vpn_info.get_filename()))
    try:
        vpn_plugin = vpn_info.load_editor_plugin()
    except Exception as e:
        print("SKIP: cannot load plugin: %s" % (e))
        continue
    try:
        connection = vpn_plugin.import_(filename)
    except Exception as e:
        print("SKIP: failure to import %s" % (e))
        continue
    break

if connection is None:
    print("None of the VPN plugins was able to import \"%s\"" % (filename))
    sys.exit(1)
# Out:
# TRY:  plugin /usr/lib/NetworkManager/VPN/nm-openvpn-service.name

# %%
connection.normalize()

print("connection imported from \"%s\" using plugin \"%s\" (\"%s\", %s)" % (filename, vpn_info.get_filename(), connection.get_id(), connection.get_uuid()))

client = NM.Client.new(None)

main_loop = GLib.MainLoop()

def added_cb(client, result, data):
    try:
        client.add_connection_finish(result)
        print("The connection profile has been successfully added to NetworkManager.")
    except Exception as e:
        print("ERROR: failed to add connection: %s\n" % e)
    main_loop.quit()

client.add_connection_async(connection, True, None, added_cb, None)

main_loop.run()
# Out:
# connection imported from "/tmp/tmpcwd9cq6s" using plugin "/usr/lib/NetworkManager/VPN/nm-openvpn-service.name" ("tmpcwd9cq6s", 7713a7d5-fd15-4a1c-9251-a93663ba810f)
# The connection profile has been successfully added to NetworkManager.
